# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk # For NLP
import re # For Regex 
import string # For punctuation
import warnings # For warnings
  
warnings.filterwarnings(action = 'ignore') 
pd.option_context('display.max_colwidth', 1000)

# %%
# read data
train_data = pd.read_csv("input/train.txt",  sep = ",")
print("Train Data has been read")
test_data = pd.read_csv("input/test_samples.txt",  sep = ",")
print("Test Data has been read")
# Out:
# Train Data has been read
# Test Data has been read

# %%
train_data
# Out:
#                  tweet_id sentiment  \
# 0      264183816548130816  positive
# 1      263405084770172928  negative
# 2      262163168678248449  negative
# 3      264249301910310912  negative
# 4      262682041215234048   neutral
# ...                   ...       ...
# 21460  522949024132112384   neutral
# 21461  522372593312350209   neutral
# 21462  522515200592052224   neutral
# 21463  523089087155437568  positive
# 21464  518290874300514304   neutral
#
#                                               tweet_text
# 0      Gas by my house hit $3.39!!!! I\u2019m going t...
# 1      Theo Walcott is still shit\u002c watch Rafa an...
# 2      its not that I\u2019m a GSP fan\u002c i just h...
# 3      Iranian general says Israel\u2019s Iron Dome c...
# 4      Tehran\u002c Mon Amour: Obama Tried to Establi...
# ...                                                  ...
# 21460  the day after newark ill be able to say ""i me...
# 21461  FEC hold farewell session for seven ministers ...
# 21462  Luca Di Montezemolo (who's last day was Monday...
# 21463  Coffee is pretty much the answer to all questi...
# 21464  Niki Lauda just confirmed to Sky that Alonso w...
#
# [21465 rows x 3 columns]

# %%
from string import punctuation
print("DATA CLEANING -- \n")
# emojis defined
emoji_pattern = re.compile("["
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)

def replace_emojis(t):
    emoji_happy = ["\U0001F600", "\U0001F601", "\U0001F602","\U0001F603","\U0001F604","\U0001F605", "\U0001F606", "\U0001F607", "\U0001F609", 
                "\U0001F60A", "\U0001F642","\U0001F643","\U0001F923",r"\U0001F970","\U0001F60D", r"\U0001F929","\U0001F618","\U0001F617",
                r"\U000263A", "\U0001F61A", "\U0001F619", r"\U0001F972", "\U0001F60B", "\U0001F61B", "\U0001F61C", r"\U0001F92A",
                "\U0001F61D", "\U0001F911", "\U0001F917", r"\U0001F92D", r"\U0001F92B","\U0001F914","\U0001F910", r"\U0001F928", "\U0001F610", "\U0001F611",
                "\U0001F636", "\U0001F60F","\U0001F612", "\U0001F644","\U0001F62C","\U0001F925","\U0001F60C","\U0001F614","\U0001F62A",
                "\U0001F924","\U0001F634", "\U0001F920", r"\U0001F973", r"\U0001F978","\U0001F60E","\U0001F913", r"\U0001F9D0"]
    emoji_sad = ["\U0001F637","\U0001F912","\U0001F915","\U0001F922", r"\U0001F92E","\U0001F927", r"\U0001F975", r"\U0001F976", r"\U0001F974",
                       "\U0001F635", r"\U0001F92F", "\U0001F615","\U0001F61F","\U0001F641", r"\U0002639","\U0001F62E","\U0001F62F","\U0001F632",
                       "\U0001F633", r"\U0001F97A","\U0001F626","\U0001F627","\U0001F628","\U0001F630","\U0001F625","\U0001F622","\U0001F62D",
                       "\U0001F631","\U0001F616","\U0001F623"	,"\U0001F61E","\U0001F613","\U0001F629","\U0001F62B", r"\U0001F971",
                       "\U0001F624","\U0001F621","\U0001F620", r"\U0001F92C","\U0001F608","\U0001F47F","\U0001F480", r"\U0002620"]

    words = t.split()
    reformed = []
    for w in words:
        if w in emoji_happy:
            reformed.append("happy")
        elif w in emoji_sad:
            reformed.append("sad") 
        else:
            reformed.append(w)
        t = " ".join(reformed)
    return t


def replace_smileys(t):
  '''
  This function replaces happy smileys with "happy" and sad smileys with "sad.
  '''
  emoticons_happy = set([':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}', ':D',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)', '<3'])

  emoticons_sad = set([':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('])  

  words = t.split()
  reformed = []
  for w in words:
    if w in emoticons_happy:
      reformed.append("happy")
    elif w in emoticons_sad:
      reformed.append("sad") 
    else:
      reformed.append(w)
  t = " ".join(reformed)
  return t

def replace_contractions(t):
  '''
  This function replaces english lanuage contractions like "shouldn't" with "should not"
  '''
  cont = {"aren't" : 'are not', "can't" : 'cannot', "couln't": 'could not', "didn't": 'did not', "doesn't" : 'does not',
  "hadn't": 'had not', "haven't": 'have not', "he's" : 'he is', "she's" : 'she is', "he'll" : "he will", 
  "she'll" : 'she will',"he'd": "he would", "she'd":"she would", "here's" : "here is", 
   "i'm" : 'i am', "i've"	: "i have", "i'll" : "i will", "i'd" : "i would", "isn't": "is not", 
   "it's" : "it is", "it'll": "it will", "mustn't" : "must not", "shouldn't" : "should not", "that's" : "that is", 
   "there's" : "there is", "they're" : "they are", "they've" : "they have", "they'll" : "they will",
   "they'd" : "they would", "wasn't" : "was not", "we're": "we are", "we've":"we have", "we'll": "we will", 
   "we'd" : "we would", "weren't" : "were not", "what's" : "what is", "where's" : "where is", "who's": "who is",
   "who'll" :"who will", "won't":"will not", "wouldn't" : "would not", "you're": "you are", "you've":"you have",
   "you'll" : "you will", "you'd" : "you would", "mayn't" : "may not"}
  words = t.split()
  reformed = []
  for w in words:
    if w in cont:
      reformed.append(cont[w])
    else:
      reformed.append(w)
  t = " ".join(reformed)
  return t  

def remove_single_letter_words(t):
  '''
  This function removes words that are single characters
  '''
  words = t.split()
  reformed = []
  for w in words:
    if len(w) > 1:
      reformed.append(w)
  t = " ".join(reformed)
  return t  

def dataclean(t):
  '''
  This function cleans the tweets.
  '''
  t = replace_smileys(t) # replace handwritten emojis with their feeling associated
  t = t.lower() # convert to lowercase
  t = replace_contractions(t) # replace short forms used in english  with their actual words
  t = replace_emojis(t) # replace unicode emojis with their feeling associated
  t = emoji_pattern.sub(r'', t) # remove emojis other than smiley emojis
  t = re.sub('\\\\u[0-9A-Fa-f]{4}','', t) # remove NON- ASCII characters
  t = re.sub("[0-9]", "", t) # remove numbers # re.sub("\d+", "", t)
  t = re.sub('#', '', t) # remove '#'
  t = re.sub('@[A-Za-z0–9]+', '', t) # remove '@'
  t = re.sub('@[^\s]+', '', t) # remove usernames
  t = re.sub('RT[\s]+', '', t) # remove retweet 'RT'
  t = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', t) # remove links (URLs/ links)
  t = re.sub('[!"$%&\'()*+,-./:@;<=>?[\\]^_`{|}~]', '', t) # remove punctuations
  t = t.replace('\\\\', '')
  t = t.replace('\\', '')
  t = remove_single_letter_words(t) # removes single letter words
  
  return t

train_data['tweet_text'] = train_data['tweet_text'].apply(dataclean)
print("Tweets have been cleaned.")
# Out:
# DATA CLEANING --
#
# Tweets have been cleaned.

# %%
x = train_data['tweet_text'].values
y = train_data['sentiment'].values

# %%
train_data = []
heading = ['text', 'label']
train_data.append(heading)
for i in range(len(x)):
    sub = []
    sub.append(x[i])
    if (y[i]=='positive'):
        sub.append(1)
    if y[i]=='negative':
        sub.append(0)
    if y[i]=='neutral':
        sub.append(0)
    train_data.append(sub)

# %%
train_data
# Out:
# [['text', 'label'],
#  ['gas by my house hit im going to chapel hill on sat happy', 1],
#  ['theo walcott is still shit watch rafa and johnny deal with him on saturday',
#   0],
#  ['its not that im gsp fan just hate nick diaz cant wait for february', 0],
#  ['iranian general says israels iron dome cant deal with their missiles keep talking like that and we may end up finding out',
#   0],
#  ['tehran mon amour obama tried to establish ties with the mullahs via com no barack obama vote mitt romney',
#   0],
#  ['sat through this whole movie just for harry and ron at christmas ohlawd',
#   0],
#  ['with davlar th main rivals are team poland hopefully we an make it successful end to tough week of training tomorrow',
#   1],
#  ['talking about acts sats deciding where want to go to college applying to colleges and everything about college stresses me out',
#   0],
#  ['why is happy valentines day trending its on the th of february not th of june smh',
#   0],
#  ['they may have superbowl in dallas but dallas aint winning superbowl not with that quarterback and owner',
#   0],
#  ['im bringing the monster load of candy tomorrow just hope it doesnt get all squiched',
#   0],
#  ['apple software retail chiefs out in overhaul san francisco apple inc ceo tim cook on monday replaced the heads',
#   0],
#  ['otti just watched it sridevis comeback remember her from the sun mornings on nta happy',
#   1],
#  ['one of my best th graders kory was excited after his touchdown today he did the victor cruzlol',
#   1],
#  ['livewire nadal confirmed for mexican open in february rafael nadal is set to play at the me livewireathletics',
#   0],
#  ['didnt want to just pop up but yep we have chapel hill next wednesday you should come and shes great ill tell her you asked',
#   1],
#  ['hmmmm november is an odd release date if true but if it becomes big enough maybe she could sing it at grammys',
#   0],
#  ['iran us delisting mko from global terrorists list in line with iran campaign tehran oct irna secretary',
#   0],
#  ['serge is amazing like hes actually god the lanky sex god saw kasabian and noel together in august it was amazing',
#   1],
#  ['larry bird is ranked th alltime not including lebron or kobe just sayin',
#   0],
#  ['good morning becky thursday is going to be fantastic', 1],
#  ['expect lightmoderate rains over visayas cebu bohol samar leyte have chance of rains tonight expect fair weather tomorrow',
#   0],
#  ['one ticket left for the game tomorrow dont miss the rematch of the nfc championship game against the ny giants hit me up',
#   1],
#  ['afc away fans on saturday all this stuff about the she said no chant its bollocks when he has the ball just turn your back on him',
#   0],
#  ['my saturday night has consisted of me watching the grey with my puppy while my parents throw rager whaa liamneesonisbosstho',
#   0],
#  ['why is it so hard to find the these days went to stores for the castle cover issue none will search again tomorrow',
#   0],
#  ['game of the nlcs and rematch of the nfc championship game tomorrow sfs gonna be cuuuuhraaaaaaaazeeeee',
#   0],
#  ['james hall live in indianapolis decth christ church apostolic tixs just adv be there',
#   0],
#  ['the heat game may cost alot moreand plus would rather see austin rivers play',
#   0],
#  ['never start working on your dreams and goals tomorrowtomorrow never comesif it means anything to act now getafterit',
#   1],
#  ['had vick and flacco needed an upgrade vick may get benched jennings back up again soon thought it was win for me',
#   1],
#  ['key largo fl yay just ur neighbor lisa sip hop away happy always watching rhom thurs',
#   1],
#  ['looks like andy the android may have had little too much fun yesterday', 1],
#  ['oooh nice tis tempting to go up the lakes with my nikon hmmmm may do that',
#   1],
#  ['black friday huge saving aerial view of city paris las vegas the las vegas strip las vegas',
#   0],
#  ['yes we all know indio vs cv is tomorrow the bell game its enough', 1],
#  ['delpham jenelle liesst she said she was alone the hospnow shes saying how weird it was for keiffers',
#   0],
#  ['lmfao his big ass get on my nerves you going to class tomorrow', 0],
#  ['im going to hong kong during that time and mama is on nov want to see them live',
#   1],
#  ['happy th mr president nick forever off the chain', 1],
#  ['dream high sucks compared to the st one', 0],
#  ['mohamed morsi egypts muslim brotherhood president instructed the supreme council of the armed forces thursday',
#   0],
#  ['cmon avila you just got tagged out by guy who looks like the kid bill murray was researching in the royal tenenbaums tigers',
#   0],
#  ['you think the boro will beat swansea im not so sure decemberjanuary is when we implode',
#   0],
#  ['at the first grammy awards held on may domenico modugno beat out frank sinatra and peggy lee for the record of the yearwith volare',
#   0],
#  ['happy birthday vow the rd anniversary', 1],
#  ['have studied all day but tomorrow im going out with friends happy omg jennette did im gonna look happy',
#   1],
#  ['good morning thursday life is fragile were not guaranteed tomorrow so give it everything youve got tim cook do it for jobs',
#   1],
#  ['twitition mcfly come back to argentina but this time we want to come to mar del plata',
#   1],
#  ['anything wondered how the aspects btwn my sunmoon faired with my rising also have venus in sagyea lol thank happy',
#   1],
#  ['my teachers call themselves givng us candywasnt even the good stuff might go to walmart or cvs tomorrow',
#   0],
#  ['broncos peyton manning named afc offensive player of the month its his th such honor second to tom bradys tied td',
#   0],
#  ['is bringing out kendrick lamar the th of december get your tickets now', 0],
#  ['may have an android phone by the time get back to school happy', 1],
#  ['andres wigan warning coys official site wigan might currently occupy th place in the premier league',
#   0],
#  ['tryst tonight best industrylocalthursday party in las vegas', 1],
#  ['what if it rained we didnt care she said that someday soon the sun was gonna shine and she was right this love of mine my valentine',
#   1],
#  ['royal rumble tomorrow night my house assemble the crew were gettin real this time haahaha',
#   1],
#  ['strange enough im going to see noel gallagher in concert tomorrow night alldaybtch',
#   0],
#  ['when my professor passes out candy and says very small amount of that may be from valentines day just so you know',
#   0],
#  ['how are they going to act in new york with the subways out they better clutch it out like eli manning th quarter',
#   0],
#  ['homegrown talent missing on signing day throughout most of the day on wednesday the video scoreboard raleigh',
#   0],
#  ['taylor swift is coming with ed sheeran june th most perf news ive heard all night',
#   1],
#  ['the great noel gallagher is about to hit the stage in st paul plenty of room here so were th row center plenty of room pretty fired up',
#   1],
#  ['id love to go for pint with jim white off ssn think he may have bit about him',
#   1],
#  ['cox there are going to be plenty of ups downs for borocardiffleicester etc until mayi hope we are still in with shout for promo',
#   0],
#  ['that sucks amazon might have some left hate that wont have it until am on tuesday though',
#   0],
#  ['happy sunday last off sadat before back to work enjoy it tweeps now to do yard work for couple hours then some fun',
#   1],
#  ['playing as the browns hc fri in madden xfacalac lost to the ravens on allmadden connectedcareers',
#   0],
#  ['cfc is the best of the premier league his overall ea sports player performance index score st place matamagic',
#   1],
#  ['nooooooooo rosanne theyve just restocked them and me going overseas sunday means cant afford them',
#   0],
#  ['the pain is far deeper than billy cundiff missed field goal gotta wake up and forget about it tomorrow orioles stayhungry',
#   0],
#  ['on november be ready to head to the movies breaking dawn part', 1],
#  ['after seeing faithreids tweet about watching the vow think may need to watch it',
#   0],
#  ['tomorrow shall consist of watching will ferrell films with my fave people and chinese food sweet',
#   1],
#  ['yeah you know just sitting around by myself listening to avril lavigne typical friday night',
#   0],
#  ['youre the closest source btwn fans team btw heard cards may sign billy cundiff any truth snarklife',
#   0],
#  ['and the same station that will air new episodes of cougar town in january has been good to us jordan pennycan',
#   1],
#  ['alex poythress had points and rebounds in his debut with kentucky during an exhibition game on thursday he played minutes',
#   0],
#  ['think may have heart attack for jason wus new collection so charlotte rampling in the night',
#   1],
#  ['if can get my equipment working correctly we will have live show on friday at pm cst with contactee ray',
#   0],
#  ['amazing concert tonight with jim white and the tcu jazz ensemblefaculty jazz combo dont miss tomorrow night',
#   1],
#  ['nationals th inning had that th quarter redskins feel didnt it coulda swore saw cundiff shank one from the mound',
#   0],
#  ['why would you still wear shorts when its this cold love how britain sees bit of sun and theyre like oooh lets strip',
#   1],
#  ['you mentioned on monday that you would be releasing colorado and nevada numbers on wednesday were those polls abandoned',
#   0],
#  ['capello says time for russia to win big match russia manager fabio capello on thursday said that he intended to',
#   1],
#  ['jackals goal jimmy martin sneaks rebound past killeen to give elmira lead bushee bellamy with the assists left nd period',
#   0],
#  ['kickoff your weekend with service evs get on the bus trip to the boys girls club is friday from hope to see you there happy',
#   1],
#  ['lmfao alright got me there good job parker and the spurs see yall jan th if get an extra ticket to that game ur goin',
#   1],
#  ['desperation day february th the most well known day in all mens life', 0],
#  ['we have similar circumstance in australia jan is australia day many first peoples call it invasion day',
#   0],
#  ['paulandhomos harry and louis are just fri eleanor is such an inspira harry is such manwho louis is',
#   0],
#  ['web apple software retail chiefs out in overhaul san francisco reuters apple inc ceo tim cook on monday replaced the heads of',
#   0],
#  ['you two may fight like cats and dogs but youre completely head over heels for each other you two are like allie and noah in the notebook',
#   1],
#  ['damn next saturday tho niggas was trynna get shit over with early', 0],
#  ['and the th one is for harry styles', 0],
#  ['this guy so much like bruno mars its crazy he may be his long lost twin',
#   0],
#  ['blog post mtvs teen mom returns for an intense third season with chelsea jenelle kailyn and leah on monday',
#   0],
#  ['the business leaders award ceremony will be held during the annual meeting in davos on the january',
#   0],
#  ['hi elif greetings from usa midwest how is school going happy turkish republic day cant wait for nov newglee yes',
#   1],
#  ['hoping to look fit tomorrow on the jeremy kyle show itvfashion', 1],
#  ['atkins me you and joe gone chill saturday of come tho', 0],
#  ['obma fails unite us he divides us by sex colorpartyage wealth nevadas st latino governor votes early for romney predicts gop win',
#   0],
#  ['grammys concert pays moving tribute to whitney houston whitney houston was given final sendoff by the grammys on thursday as halle',
#   1],
#  ['calling all voters im calling on nevadafloridaohiotuesday night is the night guys will repeat will shine for the president lets go',
#   0],
#  ['we tallied up the votes and are announcing the winners for calling all communities tune in on nov st at am cst',
#   0],
#  ['its radio rocks next week starting off with live lounge on show with bullet for my valentine on monday',
#   0],
#  ['drew peterson is untouchable no more check out these movie photos before you watch on sun at',
#   1],
#  ['im just year old still on loan for the rd time at coventry overall hopefully when return bale will still be ther',
#   0],
#  ['halloween may be the second worst holiday right after valentines day', 0],
#  ['pumped to open the season tomorrow night against georgetown womens preview mens preview',
#   1],
#  ['just found piece of candy that may have been injected with something why',
#   0],
#  ['apple shakeup mobile software boss eased out apple inc ceo tim cook on monday pushed out the powerful head of the companys mo',
#   0],
#  ['somehow managed to lose my princess leia bra on saturday im going to noel gallagher as glock at phish ie jortstank',
#   0],
#  ['may relent and get one myself but hope it doesnt come to that hopefully all the decent apps will get ported to android',
#   0],
#  ['android camera app with photo sphere now available for galaxy nexus introduced on monday android bring',
#   0],
#  ['saeed nowplaying bep ricky martin and kt tunstall great songs to get you through your sunday hate the rain',
#   1],
#  ['butlin nope its just camden eating greek food with pumpkin just another wednesday',
#   0],
#  ['are you ready to shop the new collection from hm tomorrow the grey concept from hm fashion shopping highstreet',
#   0],
#  ['faq what is skeuomorphic design and the executive shakeup at apple san francisco ca march apple ceo',
#   0],
#  ['fact of the day halloween night is papa johns second busiest night of the year behind super bowl sunday',
#   0],
#  ['no one can hold candle to queen coco if shes still doing shows in august for my wedding we have to go',
#   1],
#  ['omg ricky martin may be gay but he is one fine ass gay man', 1],
#  ['the clippers are playing the cavaliers on monday and are having night to honor israel happy wish you were in la still',
#   1],
#  ['on the bright side tomorrows chocolate day getexcited', 1],
#  ['um just learned that sunday is national chocolate day im totally taking advantage of that',
#   1],
#  ['to all ladies see you on th dec axl rose putri teaser biar gak kecewa', 0],
#  ['noel gallagher musicians are fucking idiots yeah brian may hes an idiot an idiot who just so happens to be professor',
#   0],
#  ['vow is likely to return from midsummer break in the prix de royallieu at longchamp on saturday',
#   0],
#  ['forhippies hell yea lmfaoo see you tomorrow asia baby', 1],
#  ['liampayne wanted you to know that here in argentina is going to make directioner fest november te amo te amo te amo',
#   0],
#  ['its november already christmas will be here soon then new year then valentines day then graduation',
#   0],
#  ['nowplaying michael jackson shes out of my life live at wembley july love it mjtunes',
#   1],
#  ['niggas be on the lakers dickwe still gon finish damn near first seedwhile yo team be struggling for the th spot',
#   0],
#  ['october people have principles argue passionately for them about them act on them ghandi sadat adt me',
#   1],
#  ['amber fantastic news we will reunite with barbara and jenelle on november st when teen mom premieres',
#   1],
#  ['need another viv necklace may buy myself one for valentines day nojoke', 0],
#  ['im in the bathroom bumping niggas in paris crunk ass hell like its my st time hearing it this song will never get old lol',
#   1],
#  ['just got tickets to see muse in florida that combined with the grammys two weeks prior equals really busy february for ruby and myself',
#   0],
#  ['welcome nick in manila so excited for the show on friday', 1],
#  ['battle for the th banner royal rumble basketball edition', 0],
#  ['no matter what anyone saysray lewis may be the best defensive player to ever play the game hes got heart and hes got anger',
#   1],
#  ['th album out red millionswifties grammy awards amas bmi awards reigning entertainer of the year acm yearstaylorswift',
#   1],
#  ['smooches from fido yea or nay july th was international kissing day of the human sort later in the month ca',
#   0],
#  ['its midnight on the east coast which means its birthday happy th birthday nick',
#   1],
#  ['apple ceo apologizes for errorridden new map app apple ceo tim cook apologized friday for the companys errorridden new mobile map',
#   0],
#  ['monta ellis ellis provided just five points on of shooting thursday nba playersnews',
#   0],
#  ['when teach basketball in my own school were gonna spend the st day watching larry bird videos the rest will take care of itself',
#   0],
#  ['att offers free cloud storage for ios and android att on thursday announced new service it calls att locker th',
#   0],
#  ['we are here for our th anniversary celebration you still have time to make it king dr',
#   1],
#  ['told you shane would get his thstar on rivals before signing day mcneill',
#   0],
#  ['mitch are you free on sunday to bale leaves for an hour if not no big deal you can have them for animals',
#   0],
#  ['me heart will explode need some new about avrils th album', 0],
#  ['love how skipped every category of the ntas besides the soaps couldnt give half fuck if everything else went off the air tomorrow',
#   1],
#  ['uk was in on sat and they only had the ray lewis home jersey they didnt have lot either',
#   0],
#  ['new york giants gamebygame predictions for the nd half of the season', 0],
#  ['cmon cmon does sound like queens we will rock you somehow', 0],
#  ['mashed out to niggas in paris in the club while in paris as cliche as it may sound weouthere',
#   0],
#  ['pick the chelsea team to play swansea chelseas focus now turns back to the premier league and on saturday we make',
#   0],
#  ['just had look and it seems nash to davos is done deal along with joe thornton may have to pay visit',
#   0],
#  ['my mom just texted me reminding me that grammys birthdays tomorrow how could ever forget biggestdayoftheyear',
#   1],
#  ['wow youre also percy jackson fan happy the th book of heroes of olympus will be entitled house of hades',
#   1],
#  ['esperance will be without star player youssef msakni for the first leg of the champions league final against al ahly on saturday africa',
#   0],
#  ['the sun paolo di canio says beating aston villa tonight would be like having sex with madonna legend',
#   0],
#  ['obviously am not fan of dream high and havent even watched it well watched the st epthats where heard that song',
#   0],
#  ['black history fact marsalis is the st and only artist to win both classical and jazz grammy awards in one year and to repeat the next yr',
#   1],
#  ['watching david letterman with no audience but playing like they are still there is the nd most brilliant thing ive seen tonight',
#   1],
#  ['gov mitch daniels will announce his indiana supreme court pick at am will the rd time be the charm for female member of the panel',
#   0],
#  ['goodnight everyone talk to you all tomorrow happy shall leave you with harry styles',
#   0],
#  ['most common nights to order pizza nye jan day before thanksgiving super bowl sunday halloween',
#   0],
#  ['the grey and yellow gold wedding puzzle is now up with the first piece being unique twotone dress by',
#   1],
#  ['listening to kendrick lamari dont even want to get hair cut tomorrow', 0],
#  ['harakah iran army monitoring all ships in gulf tehran oct senior commander of the islamic revolution gu',
#   0],
#  ['ht norwich spurs weve edged the st half without creating any clear cut chances bales had couple of decent long range efforts',
#   0],
#  ['guys the marijuana law in colorado oregon and washington can pass this tuesday highhopes',
#   1],
#  ['breezin won the best pop instrumental performance at the th grammy awards',
#   1],
#  ['pacino is going to play joe paterno this is the nd time he has starred in film that has the line say hello to my little friend snl',
#   0],
#  ['not wearing make up to dublin tomorrow until im getting ready for the party help',
#   0],
#  ['snow may fall for parts of cny the next few days find out where the best chances will be at am on tv online',
#   0],
#  ['it seem like austin rivers is tryin to had to get bucket feel em tho my st game in the league was trying hard too',
#   0],
#  ['cofield draws leadoff walk in top th zaharion at the plate', 0],
#  ['aww my celebrity day is this thursday also going as jennifer hudson though happy',
#   0],
#  ['miss you and better get juge kiss and hug tomorrow night because you will be at joes',
#   1],
#  ['took me ten clicks to figure out where to early vote in colorado that site doesnt say what you need to bring cmon',
#   0],
#  ['sat down to watch michael jackson this is it on dvd xx', 0],
#  ['on the set of the axis of the nigerian economy airing every tuesday pm on nta international dstv',
#   0],
#  ['text from my dad you like charles dickens obvs looking at my amazon wish list too late for sunday why th surprise',
#   1],
#  ['upset alert in acc mens soccer maryland down to wake forest late in the ndand down man after an earlier red card',
#   0],
#  ['really bored of this host on super sunday doing nothing but talk and rave about man utd biasprick',
#   0],
#  ['may have missed out seeing noel fielding and rich fulcher today but did just see tom tilley samsimmons',
#   0],
#  ['thankfully hes in germany now and comes home in january still dangerous though',
#   0],
#  ['looper was amazing now to the theatre to see simon callows the mystery of charles dickens loving my wednesday off work happy',
#   1],
#  ['if youre an october baby then happy valentines day to your folks they have an annual memory',
#   1],
#  ['negros and nigglettes all who would like to attend the aap rocky concert on november th at starland lemme know tickets are only',
#   0],
#  ['wish maddie luck next saturday she has solo audition for britains got talent happy ellie xxxxx',
#   1],
#  ['nfl victor cruz went public this month with his desire for new contract on tuesday the giants rec football',
#   0],
#  ['of joe pa masks at penn state sat or will psu by allow then in the stadium is it bad to wear it',
#   0],
#  ['thats crazy im more jealous of going to joe pas grave was sad saturday when walked past where the statue should be',
#   0],
#  ['mizzou commemorates its win over kentucky with tshirt no really dr saturday yahoo sports fb',
#   1],
#  ['who should the rock face for the wwe title at the royal rumble just voted rockpunk would be st to see',
#   0],
#  ['lol that was our only year we may have had chance at the superbowl now we must wait until nick foley',
#   0],
#  ['thinking bolt action may have to be in the cards for valentines day or something',
#   0],
#  ['happy valentines day everyday is the th', 1],
#  ['have to finish reading paterno by tomorrow so can watch football sunday and monday and prepare for the nbak release pagesleft',
#   0],
#  ['it may be indian time tonite becky happy xx', 0],
#  ['just watched the campaign with will ferrell and zack galafianakis good fun for wednesday hilarious',
#   1],
#  ['season ends with superbowl in first week of february', 0],
#  ['your review reminded me still need read the very st percy jackson book heroes of olympus is an offshoot series from it',
#   0],
#  ['crazy was in meeting with an old nba player that was picked rd before larry bird',
#   0],
#  ['this sunday new york giants are going down steelers', 0],
#  ['as an introduction to literature we wrote about the woman in black not something particulalry want to read may just cry shitmyself',
#   0],
#  ['flipping did the other new is in today northern lights get payed tomorrow',
#   0],
#  ['just finished rehearsing with we are ready for the kendrick lamar show tomorrow shout outs to wvu',
#   0],
#  ['posted photos on facebook in the album super sunday wid shobhit bhatia', 0],
#  ['been watching allaccess kentucky every wed and it has been making me like these young dudes on kentucky',
#   0],
#  ['nick all day and on my powder puff pants looks like im gonna be stud tomorrow under the lights starcevich jeffries',
#   1],
#  ['roy just go youre bigger embarassment than capello and mcclaren', 0],
#  ['black friday deals nikon megapixels digital slr camera with mm nikkor vr lens black nikon',
#   0],
#  ['han mon dieu le remix de am the best dans dream high je meurs xddd', 1],
#  ['you do not want to miss this tomorrow night rj is moving to maryland soon and we have truly epic set planned',
#   0],
#  ['dont forget mitch daniels is going to be on steven colberts show thursday think this will come up as topic',
#   0],
#  ['mane gotta see that denzel movie tomorrow shit look like its gone be good oneditto im going to try to go tomorrow',
#   1],
#  ['would think you would do that if you are running for potus it may be part of your job someday',
#   0],
#  ['grammy and caleb going freeport tomorrow chalee', 0],
#  ['but how you gon handle it if you are announcing on super bowl sunday you might put that gold back in yo grill',
#   0],
#  ['dan have plans to go to cvs before work today and get something that may be what get im going to quarantine myself today',
#   0],
#  ['iphone apple ceo pledges to improve new map app apple ceo tim cook apologized on friday for the companys er',
#   0],
#  ['full moonoct th you can read more if you have your sun sign in libra scorpio sag cap aqua or pisces',
#   0],
#  ['drew peterson may be convicted but there is still conflict going on whenwillitend localnews chicago',
#   0],
#  ['paterno wouldnt be charged all hearsay on him and he did do his job minimal as may be he reported it rest is speculation',
#   0],
#  ['with all bensons attention frankie feels like forgotten stepchild lets founding father him so he know we will never forget nd place',
#   0],
#  ['police protesters clash at republic day march in turkey on day marking the th anniversary of the founding',
#   0],
#  ['will be participating in google hangout with tomorrow im super excited check it out',
#   1],
#  ['why do you think murray may leave no way team drafts him before the th or th round',
#   0],
#  ['aww love you austin rivers and happy to see you get start in st nba gamebut its against my boys lets go spurs spurs nba',
#   1],
#  ['ive paid few quid for jim white record if recall correctly but im not in the biz so may well be missing the point',
#   0],
#  ['mines personal thinking tebow is better then flacco dont care how bad he played sunday',
#   1],
#  ['another center gagner is good cheap nd line option that we can afford and keep the kids',
#   1],
#  ['im still shaking my head at that decision and that the heat knick are actually playing tomorrow at msg',
#   0],
#  ['the glass may be rising but its not getting any warmer here lago del desierto argentina',
#   0],
#  ['wish could make that trip to athens on tuesday', 1],
#  ['apple software retail chiefs out in overhaul san francisco reuters apple inc ceo tim cook on monday pushed out the powerful hea',
#   0],
#  ['want to watch the grey for the th time', 1],
#  ['im hosting the day party spartacus friday from and then spy in raleigh that night',
#   0],
#  ['eli manning hopes the giants can uplift the spirits of the millions affected by sandy in ny with their game against the steelers on sunday',
#   0],
#  ['the mccormick placerite here by the hyatt hotel on like rd nd king dr', 0],
#  ['fabio capello from what ive seen these days can assure you russia are capable of getting good result vs portugal tomorrow cantwait',
#   1],
#  ['not necessarily in nevada it may help obama because its one less vote for romney but know what you mean hah',
#   0],
#  ['parker leonard steal okcs thunder ninety minutes before tipoff thursday night at the att center oklahoma ci',
#   0],
#  ['really do hope they finish the trade by tuesday or wednesday gagner is real solid player and could help the sabres',
#   1],
#  ['after watching the campaign again have realized that step brothers is still the funniest will ferrell movie but this one is in nd place',
#   1],
#  ['hes on the plane to amsterdam now bet hes not in class tomorrow', 0],
#  ['really wanna go to one of his things did you watch his new thing on channel last friday xx',
#   1],
#  ['may be the only girl on the face of the earth that doesnt find channing tatum attractive callmecrazy justsayin donthateme',
#   0],
#  ['obama may have been better off staying put personally im glad hes back on the trail hes helping move people to mitt',
#   1],
#  ['cold pizza and mass effect want my leg healed going to look up some voodoo shit ill be walking jumping and running tomorrow',
#   0],
#  ['remember cupid at convo last year with the bomb candy bar if you liked that youll love next tuesdays tr',
#   1],
#  ['on november me my mom and my sister are going to see breaking dawn part judgeus',
#   0],
#  ['channing tatum will be in white oak tomorrowfor all you stalkers out there',
#   0],
#  ['elliott fly that saturday the th from detroit to amsterdam then up to newcastle',
#   0],
#  ['my dad the builder are talking about city and it turns out the builder is sat the row behind me at the aston villa game fuck sake',
#   0],
#  ['games played during the week are now more interesting than super sunday',
#   1],
#  ['hulu video game trailers launch trailer check out the launch trailer for mass effect added fri oct',
#   0],
#  ['id watch cougar town over this any day january on tbs very funny firedooley',
#   1],
#  ['stacie just hit me up and said my packages might be up here tomorrow if thats the case im not going to the rave in san fran priorities',
#   0],
#  ['of course its aston villa played them off the park on saturday bring it on',
#   0],
#  ['matching cofield in sacks but this is only the st preseason game so well see',
#   0],
#  ['give me mins with candy the dancer from deja vu im nutting on my th pump she that bad lol',
#   0],
#  ['kevin hart show at msg on november th is going to be beautiful', 1],
#  ['do you know they may not but were so fond of all the countries uhhappy republic day',
#   1],
#  ['cof cof someone is going to germany on november oh really envy you happy',
#   1],
#  ['thank you snow for cancelling classes today now you may stop snowing so that can drive to chapel hill tomorrow id really appreciate it',
#   1],
#  ['chick in my class said flacco is the best qb in the league why is chick talkin football cant wait for class tomorrow lol',
#   1],
#  ['entrepreneur angelinvestor pitch in on the new birthday party super bowl sunday treat',
#   1],
#  ['oilersmobile july sam gagner nice to have you there for at least another year',
#   1],
#  ['think might go see flight tomorrow just because denzel washington', 1],
#  ['mohamed nasheeds press brief about coni report aug via', 0],
#  ['wish the best of luck to the boro football players and hope they kick butt saturday for shaun winitforshaun',
#   1],
#  ['calling all reality tv fans were inviting li reality tv stars to join google hangout on sunday and you can too',
#   0],
#  ['honesty is often best policy fabio capello russia coach was hoping ronaldos injury was more serious so he couldnt play tomorrow',
#   0],
#  ['bestie we gotta go see flight with denzel washington comes out friday seems so good',
#   1],
#  ['dont know what yall will be doing on november but ill be in google hangout with jordy nelson squeeeeee',
#   0],
#  ['dinner in athens with my friend preparing for our game on this saturday olemiss georgia',
#   0],
#  ['elena happy most def think when you come tomorrow the boys will be here',
#   1],
#  ['this is austin rivers st game and people sucking him he rookie chill', 0],
#  ['hello may ask how did you get on set of castle', 0],
#  ['throwback thursday daddy and joe pa rip to in my eyes still the most winningest coach in college footbal',
#   1],
#  ['gagners agent says talks continue will have hearing on friday if no deal msm just proved youre clueless',
#   0],
#  ['im enjoying celebrity juice instead of sleep going to be fooked tomorrow though',
#   1],
#  ['the woman in black the legendary ghost thriller touring to dubai and abu dhabi in november december more',
#   1],
#  ['can it please be wednesday and potus has been re elected then we can move this country forward',
#   0],
#  ['jacksonville really sound like the move tomorrow', 0],
#  ['asimplelife opens tomorrow at lees star in san fran roger ebert called it one of the years best films',
#   0],
#  ['nooooooooo maybe you can just look over it right before the test tomorrow and do that first',
#   0],
#  ['hcafc loan keeper ben amos named in the england unders side to face azerbaijan next thursday and norway on sept',
#   0],
#  ['norv turner calls play action pass on st goal at the halfyard line rivers throws pick chargers',
#   0],
#  ['celebrity juice best thing on about thursday', 1],
#  ['my friends and are betting joe wets his pants when he sees the whopping mittens will get nov',
#   0],
#  ['waheed proposed mdp to join the gov prior conis verdict feb controversial power transfer refrained mdp joining the govt',
#   0],
#  ['me and booked in to see good day to die hard on february valentines day',
#   0],
#  ['frankie think im gonna have date with my bed tomorrow me same thats my boy',
#   1],
#  ['pray for mohamed morsi the new president of egypt that he may continue to be leader for freedom and peace',
#   1],
#  ['may spend lot of my free time riding on random elevators hoping for chance encounter with bill murray',
#   1],
#  ['wvu goes for it on every th down is our kicker worst than cundiff', 0],
#  ['mac was it becky cause she told me about it ill figure it out tomorrow', 0],
#  ['axl rose needs to just give up now not later not soon not tomorrow now', 0],
#  ['dr mohamed morsi announced as egypts st elected president after the glorious th of jan revolution congratulations to egypt happy',
#   1],
#  ['shout out to my boy who fights tomorrow night on the las vegas rfa card hes put in the work so dont need to wish him luck',
#   1],
#  ['dec th know its so far and near the end of sagittarius but im full blown sag girl happy lol',
#   1],
#  ['if youre on the isle of man next thurs ill be talking about safe house and signing books at waterstones from pm',
#   0],
#  ['pbr bring you jim white at the lounge on october rd at pm', 0],
#  ['happy halloween starting this wicked wednesday off listening to pink floyd and leonard cohen get to take my boys out tonight yay',
#   1],
#  ['wonder what cortese is thinking after watching that st half of total wank as for boruc you are disgrace and complete twat saintsfc',
#   0],
#  ['sad wont get to see on the challenge battle of the seasons tonight sad guess ill have to wait until next wednesday',
#   0],
#  ['austin rivers needs to get stronger spurs guards muscling him tonight he started and just now scored in th hornets',
#   0],
#  ['july th national milk chocolate day you might say milk chocolate is the star of the chocolate cont',
#   0],
#  ['on sunday november th olympus experts will be on hand at the currys store in cambridge from am until',
#   0],
#  ['happy valentines day only if you live in brazil otherwise its just another irritating monday',
#   1],
#  ['okay me and are about to watch the woman in black this may be terrible night',
#   0],
#  ['liampayne saturday buy my ticket for the tmhtour in belgium im so happy',
#   1],
#  ['this goes way too fast its been already year that saw avril lavigne in concert happy october one of the best day of my life happy',
#   1],
#  ['heh just remembered forgot to watch jonathan ross guess ill watch it tomorrow was watching another show and forgot schmeh',
#   0],
#  ['gambled on chocolate day as successful theme day at workturns out chdn do like chocolate wed is gross day hope kids like gross stuff',
#   1],
#  ['harry redknapp is set to hold talks over the blackburn job on tuesday as he prepares for return to management mail',
#   0],
#  ['go to the bell game tomorrow ill take you for littlle whippa', 0],
#  ['if you fancy joining in our to tour of the world foods of london come sample taiwan on thursday',
#   1],
#  ['so many choices of gigs this saturday night the ibb at the rugby club which one there are two up twmpath and',
#   0],
#  ['how does it compare to diablo iii regardless of how fair that comparison may be',
#   0],
#  ['how many continents was the challenge filmed on okay what did you fail nd grade',
#   0],
#  ['were going to be at boys and girls club to clean tomorrow at am they told us to bring boots and gloves all are welcome',
#   1],
#  ['last hectic day in office weeks in asia st to ifeat in singapore then taiwan hk chinathen wks of jet laggets to me every time',
#   0],
#  ['david letterman had an interesting show on monday he is located in new york city because of the hurricane he',
#   1],
#  ['anonymous asked just realized while watchin friend that the youtube account that uploaded the video is',
#   0],
#  ['november my birthday month election day weekend in san fran with naples for thanksgiving lots of friends family yes',
#   1],
#  ['yes got an email reminder from nikon about this saturday event if no go back then we will join the photo exhibition launch',
#   0],
#  ['ive been on tv few times now still waiting for the call from itv about dancing on ice though starting to think may be too famous',
#   0],
#  ['slap shot nash back from injury skates for davos rick nash of the new york rangers returned to action in switzerland on tuesday',
#   0],
#  ['eleanor was just fan when she met louis its funny bc she probaly wasnt fan like she may have known who they were but she wasnt fan',
#   0],
#  ['nikon prostaff cant wait to get it on and shoot tomorrow', 1],
#  ['hope they make sure to take care of eli manning giants vs pittsburgh on sunday nfl',
#   1],
#  ['they canceled the frankie date that was supposed to be tomorrow so now everyone is going to the rescheduled show in south bend',
#   0],
#  ['ive got tickets to see leonard cohen in rosemont il on november that cant use anyone interested face value is about',
#   0],
#  ['also mancs going on about it was there youthnd team last nightthought they put out decent side seeing they have afc on sat',
#   0],
#  ['come on romney may not be able to vote from britain but completley support you good luck',
#   1],
#  ['wwe raw should be interesting next week the road dogg returned to wwe at the royal rumble and shawn michaels is going to be on raw monday',
#   1],
#  ['im far too stressed about finishing this essay for tomorrow so shall minimise it and play temple run problemsolved',
#   0],
#  ['did all my homework thats due in for later this week instead of the homework thats due for monday and tuesday twat',
#   0],
#  ['saturday night live jeopardy skits with will ferrell', 0],
#  ['kendrick perkins led the league for the th year in row in spm scowls per minute literally laughed out loud',
#   1],
#  ['my mufc xi for super sunday de gea rafa rio evans evra clevz nani young roo chicha rvp what about you',
#   0],
#  ['eli manning best th quarter qb in the game', 1],
#  ['dont want love like jonny and june want love like blake and miranda', 0],
#  ['lin picks up loose ball and just trucks stuckey unfortunately thats not allowed to bench with th foul as pistons reclaim lead',
#   0],
#  ['not sure what im going to be for halloween yet sun shine is just too obvious larry bird is the front runner as of right now',
#   0],
#  ['if cundiff wouldve made the field goal sunday couldve been eatin free in sub at subway for lunch',
#   0],
#  ['me personally dont see grammy playing afl again still but think hell turn to something else now best of luck with what may be next',
#   1],
#  ['feel do bad my boo asia bday event maybe cancelled for this sunday was soooo looking forward to it',
#   0],
#  ['dirty jim had to close that one out if not he may have started hearing comparisons to cundiff in this town',
#   0],
#  ['after the mid tennessee vs western kentucky game hear theyre gonna play the nd annual ogalla nebraska snail chuckin pageant',
#   0],
#  ['were sophia grace and rosie cant wait to see you on ellen tomorrow xxx', 1],
#  ['im going to bullet for my valentine at academy glasgow in glasgow united kingdom mar',
#   0],
#  ['its friday and the soul train is firmly parked in pri for the soul show on the radio cmon perth get your requests in for the next hour happy',
#   0],
#  ['people power travels to egypt to see how the april th activists have been faring since mohamed morsis election',
#   0],
#  ['next tuesday is ds chocolate day with halloween right around the corner this is sure to curb your candy craving',
#   0],
#  ['shit yeah its thursday russell howards good news and celebrity juice is on',
#   1],
#  ['pretty good thursday night with if only rivers would stop sucking so bad qualcomm stadium',
#   1],
#  ['my heart is gold my twat is glass cmon baby cant ya see yesa glass twatbetter known as womb with view lol',
#   1],
#  ['im so good at gambling just owned las vegas leaving tomorrow morning for weekend of dog sitting and homework not bad week',
#   1],
#  ['whos on google we want you to participate in live google hangout with animalsense next wed at',
#   0],
#  ['can not change yesterday can only make the most to day and look with hope toward tomorrow anonymous',
#   0],
#  ['had wonderful workshop on thursday at sag office with carol nadell of selective casting she is such',
#   1],
#  ['nd the ryan budget was from many years ago most recent didnt include that and mitts said many times hes the president and',
#   0],
#  ['why does everyone want to give eli manning credit for every win the truth is sundays game should have been blowout',
#   0],
#  ['charles dickens may just have been me in another life thisisme', 0],
#  ['going to buffalo wild wings tomorrow with my life long friend israel and my brother thats what call good night knicksnation',
#   1],
#  ['pm tomorrow night have date with denzel flight cant wait', 1],
#  ['apple ceo apologizes for errorridden new map app apple ceo tim cook apologized friday for the companys erro',
#   1],
#  ['new die hard movie coming out feb looks like bruce willis is going to be my valentines dateo',
#   1],
#  ['liked video anonymous remember remember the th of november', 1],
#  ['hello man in pointy multicoloured snake skin cowboy boots suit and axl roses hair youve made my friday heart even happier',
#   1],
#  ['real america will stand up for itself on tuesday and make it count mitt is ready to lead us out of our jimmy carter funk were in',
#   0],
#  ['dana asked when chael started his job with fox and chael response was oct st on fuel tv',
#   0],
#  ['hmm think am living the movie ground hog day grandma jan and isaac are back again this weekend',
#   0],
#  ['me ill bring your birthday card in on friday kane aw really its the thought that counts id prefer tv twat',
#   1],
#  ['nfl news new york giants gamebygame predictions for the nd half of the season football nfl nfceast',
#   0],
#  ['gotta go see flight tomorrow denzel is the greatest actor ever', 1],
#  ['damn just got cougar town cupcakes and was going to bring them tomorrow to share shouldnt eat all alone',
#   0],
#  ['romo mentioned that he was from brawley and hell be at the bell game tomorrow happy',
#   0],
#  ['anonymous asked beard tweetd that intense message at on tuesday abit after the halloween partys and she',
#   0],
#  ['ladsontour mon the boys theres only thing missin banjoooooooooooooooooo how nooooooooo',
#   0],
#  ['black friday deals olympus omd em mp live mos interchangeable lens camera with inch tilting oled tou',
#   0],
#  ['kobe in the th is like eli manning beware', 0],
#  ['also this is about to be the best night of my life joe pa vs somebody may die hahaha',
#   1],
#  ['wednesday and thursdays will be struggle at work once the champions league resumes gmt',
#   0],
#  ['also need to be at least accredated in act or rebt before the end of th yr',
#   0],
#  ['axl rose through the bose in my rolls through the concrete see rose still rose counted up million dollars fore that sun rose',
#   0],
#  ['if one more commentator references how smart the dook players are may just turn this mess off overratededucation dook',
#   0],
#  ['played dishonored darksiders and mass effect in the last hours', 0],
#  ['scariest man alive kendrick perkins is close nd ray lewis is probably the only human being ever not born with an indoor voice',
#   0],
#  ['amazon has opened an online store for black friday days before the shopping event is scheduled to take place haha this is war',
#   0],
#  ['just whip it baby whip it all night welcome to soul train fandom may you never leave',
#   1],
#  ['chargers may go but that will make playoffs in afc nfc teams must win games fact',
#   0],
#  ['late halloween party next saturday going as thriller michael jackson is it to controversial to hold baby doll too',
#   0],
#  ['been sat in my room sticking down postcards of tehran on the wall for god knows how long why has nobody invented teleporting machine yet',
#   0],
#  ['nac lol ill be able to do it saturday or friday night after the greek show',
#   1],
#  ['nation hellyeaa ahaha one of the st streets on niggas', 1],
#  ['hahahaha spanish people and nadals box all smiling after the break in the th set hahahahahaha rewatchingaofinal',
#   1],
#  ['sick beard download finished rd rock from the sun dick puts the id in cupid',
#   0],
#  ['sundays in the sag is like friday in idahoboring as fuck', 0],
#  ['hell be the eli manning of the nbathey both of the best th quarter players in their sports closer killerinstinct splapa',
#   1],
#  ['on monday go back to my old job for the fourth time my life is the groundhog day movie',
#   0],
#  ['if the steelers play as good as they did sunday say keep the bee uniforms on all the way to the superbowl steelers',
#   1],
#  ['harry redknapp is being heavily linked with the position as blackburn manager today however qpr may have begun courting him already',
#   0],
#  ['dont think they can hold it for the rest of the season theyre bye week may just throw them off dunkno bout the ravens',
#   0],
#  ['yo im excited for royal rumble might book that monday off work so can watch it',
#   1],
#  ['procrastinating need to get ready for the th district chicago police rally against violence chitown cheer will be performing king dr',
#   1],
#  ['will you have lunch with me tomorrow nightrandom hoe thats hitting on castle nooooooooobeckett',
#   0],
#  ['happy th birthday nick hope its one of the best youve accomplished so much already and so much more to come love you',
#   1],
#  ['factsaboutme when was born on that day it was the nd day of chinese new year immediately gotten lots of redpacket happy',
#   1],
#  ['work almost over with then these negros wont see my face till monday night',
#   0],
#  ['ill be doing the senior bowl fun run with my niece next saturday', 1],
#  ['monta ellis ellis had just two points on of shooting on friday against nba',
#   0],
#  ['if any baltimore team mascots come up missing st person of interest should be billy cundiff or the redskins mascot is taken blame him',
#   0],
#  ['want to go to chapel hill tomorrow for halloween', 0],
#  ['no youth tomorrow come to fall festival also this sunday high school will attend main service with the adults for super sunday',
#   0],
#  ['hope can get ticket to the concert in belgiumyou cant order them till saturdaypfffs',
#   1],
#  ['tech news apple software retail chiefs out in overhaul apple inc ceo tim cook on monday replaced the heads of it',
#   0],
#  ['lowfat oasis edmonton sun lowfat oasisedmonton sunpoor noel gallagher up there all alone with his new ba',
#   0],
#  ['rd and goal at the and rivers throws int terrible pass by rivers bad decisions cost games geez half time sd',
#   0],
#  ['egypts morsi gets red carpet welcome in iran tehran aug egypts mohamed morsi is in iran for the first visit',
#   1],
#  ['need shower and to start getting ready but im just sat in bed blogging and watching celebrity juice',
#   0],
#  ['we have melbourne cup woop thats fab horse racing day we have christmas easter good friday australia day idk heaps haha',
#   1],
#  ['is on the radio instead mt its the first week without any waterloo road going to be boring thursday',
#   0],
#  ['lmao from garage in boro my mate went in for drink on sunday night but they wouldnt serve him because it was too late so',
#   0],
#  ['ground hog day is such good film sunday is for food and films sunday', 1],
#  ['if seattle and portland were knit together and covered by the california sun youd have san fran kinda love it',
#   1],
#  ['estou ouvindo brown eyes live friday show with jonathan ross lady gaga via',
#   0],
#  ['niggas was really fighting at the gas station sat night tho', 0],
#  ['what about holland countdown to ufc silva vs bonnar debuts tuesday on fuel tv',
#   0],
#  ['hmmm it occurs to me that havent received residual check in nearly year now think should email sag tomorrow',
#   0],
#  ['buenos airesargentina late wednesday approved law to lower the legal voting age to in move that could',
#   0],
#  ['only if they lose the nfc championship like last season fucking overtime we get to redeem ourselves tomorrow though happy',
#   0],
#  ['apples increasing skeumorphism the wood and leather effects tim cook canned scott forstall no more dodgy effects',
#   1],
# ...
#   1],
#  ['gop has set the bar very low with th cycle promoting grossly unamerican idea potus as elected autocrat civics',
#   0],
#  ['in your defensemy love of dickens original may be regarded unnecessarily high in my eyes because of the history have with it',
#   0],
#  ['tonight wedmike slomo brenner solo opening for jim white at tin angel pm cmon out',
#   0],
#  ['dtn kazakhstan capello ill tweak lineup for azerbaijan gamecoach fabio capello said monday he will tweak the',
#   0],
#  ['spending my last night in indianapolis with my mom and cousin headed to idaho tomorrow',
#   0],
#  ['lw well im currently on holiday in portugal coming home tomorrow then going to poland on tuesday for holocaust memorial trip',
#   0],
#  ['about to watch the nd half of season of breaking bad on my long flight to hong kong buzzin',
#   0],
#  ['may ask my doctor for ambien on election night id rather sleep through it and hope wake up to footage of mitt crying over his loss',
#   0],
#  ['cheaper carbon replaces silicon in solar panels washington nov ians researchers have built the first solar',
#   0],
#  ['fuck looking at art tomorrow im going straight to the side of town where can find chief keef ohhyeahh',
#   1],
#  ['cant wait to hear tomorrows cmag meeting about horny coni report baages wait watch you will be grilled tomorrow cmag hope',
#   0],
#  ['its wednesday you know what that means new episodes of the challenge battle of the seasons american horror story asylum',
#   0],
#  ['today was national kissing day ill have to make up for the loss tomorrow',
#   0],
#  ['tomorrow is the last day for early voting here in nevada if you havent already go vote dont wait til tues to do so',
#   0],
#  ['taiwan wins visa free travel to us six taiwanese tourists arrived in new york on thursday as the first from the',
#   0],
#  ['so thought yesterday was tuesday im thinking today will be little like the movie ground hog day',
#   0],
#  ['betstylelounge this saturday will be turnt to the max come see me and rock out th and king dr',
#   1],
#  ['man utd arsenal on sat sees the best defence afc in the league conceded pgame against the best attack utd scored pgame',
#   1],
#  ['watching sundays harry and paul good it is too wellobserved and fearsomely dry',
#   1],
#  ['we do not live in ground hog day we dont live with victim mentality today rough but tomorrow wont be the same el leadership',
#   0],
#  ['was thinking of harry redknapp for the job for the past few days now would be an absolute coup cmon shebby',
#   1],
#  ['nowplaying jim white crash into the sun', 0],
#  ['remember last new years and sat there for hours watching kasabian live at the',
#   0],
#  ['many rumours floating about that harry redknapp may be interested in the blackburn job what do you all think',
#   1],
#  ['new glory gang music janet at the superbowl on soundcloud', 0],
#  ['this bitch just put frog back on lmfao throw back thursday', 0],
#  ['no you may not kick it tribe called quest answering text from billy cundiff',
#   0],
#  ['happy valentines day to you that may have one', 1],
#  ['my body is exhausted walked from th and jeffery to the lakefront where accidentally sat on dead fish to th and king dr and back',
#   0],
#  ['info taetiseo will perform on love in asia tomorrow at pm kst kbs will broadcast the concert on november at pm',
#   0],
#  ['game day arsenal ladies vs turbine potsdam champions league last st leg get down and support the gooners uwcl alfc',
#   0],
#  ['video game trailers launch trailer check out the launch trailer for mass effect added fri oct',
#   0],
#  ['no joke got voicemail yesterday saying happy valentines day instead of happy th of july wow not sure what that is all about',
#   1],
#  ['my mama going to jacksonville saturday would go but she want let me im on punishment',
#   0],
#  ['great seeing im host of google hangout romneyrally wednesday of want invite let me know lynndebate',
#   1],
#  ['nikon has once again proven its small world after all with the latest herald sun',
#   0],
#  ['come out on monday to watch the woman in black the model un free entry concessions donation ssu',
#   0],
#  ['niggas in paris was playing in the waiting room at the clinic and this old lady sat tapping her walking stick and bobbing her head so cute',
#   1],
#  ['and to the girls in front of us that sat down and played temple run the whole time why did you even come confused',
#   0],
#  ['loved the hair style from fridays jason wu new york fashion week show were giving you the stepbystep to',
#   1],
#  ['chinese on top of the international holidays we have chinese new year evechinese new year day chap goh mei th day',
#   0],
#  ['too soon amazon opens black friday deals store thanksgiving is weeks away the world series only ended on sund',
#   0],
#  ['may be its true becouse triple arm has broken for reel or may be he will come back at the royal rumble',
#   0],
#  ['boring xfactor seen it all before xfactor lets have something new for autumn and no more dancing on ice in january',
#   0],
#  ['went to see the mystery of charles dickens at the playhouse theatre west end last thursday starring simon callow its must see',
#   1],
#  ['oh yay my mom just told me that my grammy is coming tomorrow woot woot loveher',
#   1],
#  ['unfortunately am wathcing all manifestation related to republic day and just see that we are really far away st century',
#   0],
#  ['this may be little forward secretcountry but can you imagine the sex miranda lambert blake',
#   1],
#  ['the ending to the grey may be one of the most bad ass endings to movie ive ever seen',
#   0],
#  ['totally curious with dream high wanna watch this drama asap wanna compare it with the st one still theres loooooooong holiday',
#   0],
#  ['safe and sound at narita airport feels good to be back at the land of rising sun',
#   1],
#  ['its so early here in germany my american friends are just now getting drunk off to prague knuckleheads talk to you on sunday czechrep',
#   1],
#  ['can not let be let down game sunday with houston and san fran coming up gotta focus on beating tennessee jayisourqb',
#   0],
#  ['whos going to israel this saturday', 0],
#  ['iran army monitoring all ships in gulf tehran oct senior commander of the islamic revolution guard corps',
#   0],
#  ['soul train halloween party sat oct adv tixx wt out costume at the door', 0],
#  ['cant wait for you to come to dublin on monday so excited to see you happy',
#   1],
#  ['bj penn vs nick diaz replay on fueltv id pay to watch it nd time', 1],
#  ['taylor swift to cohost grammys with ll cool new york oct ani taylor swift has been chosen to present',
#   0],
#  ['my hormones are spiral out of control am crying over the jeremy kyle show for not the st or the nd but the rd time today wut',
#   0],
#  ['ah okay was hoping to see you out friday next time im staying at harrys we should meet up in kingston xx',
#   1],
#  ['lol you mean pronounce it idk eitherhmmi like to say it like hairmay or hairmess lmfao idk okay happy',
#   1],
#  ['lol maybe friday since im going to georgetown', 0],
#  ['bird on the wire is one of the st songs learned as child and now daddy and go see leonard cohen',
#   0],
#  ['next thursday or friday they play maryland in new york for the first real game',
#   0],
#  ['be sure to watch cougar town its friends minus all the best actors plus wine coming in january right after shovin buddies',
#   1],
#  ['arsenal ladies are at ht with ffc turbine potsdam in their womens champions league last st leg clash at borehamwood wucl',
#   0],
#  ['thursday nights just wont be the same without waterloo road', 0],
#  ['harden got pts in the rd damn maybe lin and harden can get my rockets to the playoffs',
#   0],
#  ['not everyone has the same image of sexy there are plenty of men out there who may think im built like ray lewis wit weave oh well',
#   1],
#  ['valentines day by linkin park may not be the newest song but its one of the best',
#   1],
#  ['community cougar town friday night lights glee mad men modern family six feets under skins terra nova the wire',
#   0],
#  ['land conservation announcement monday gov mitch daniels and lt gov becky skillman will make lan nashville',
#   0],
#  ['ryan reynolds may be back for prequel or sequel to safe house with or without denzel washington script is in the works',
#   0],
#  ['oh hey have another reason for you its national chocolate day on sunday happy',
#   1],
#  ['dinner with my dad and tony parker with last second game winning shot what great nightjust in time to be ruined by tomorrow',
#   1],
#  ['post of the night anonymous id excvjkr fri no this thread is like watching monkey fuck coconut',
#   0],
#  ['apple ceo apologizes for errorridden new map app video apple ceo tim cook apologized friday for the company',
#   1],
#  ['he just got completely utterly lost its not like there was viable nd option everyone knew it was parkers shot',
#   0],
#  ['congrats to djs rd grade team going to the superbowl ill be there cheering',
#   1],
#  ['whos going to go see breaking dawn part with me cmon', 1],
#  ['the two lukes austen and dickens playing at nelson bay diggers club this friday go check em out if you live in the area',
#   0],
#  ['yes thank you janine saw kelsey grammer wed night at sag but didnt talk politics there lets take hollywood back',
#   1],
#  ['st official release on is out now eott with rmxs from haze northern lights instrumentals',
#   0],
#  ['big game for tomorrow away vs the knicks at msg personally think knicks will win first game msg crowd sandy disaster',
#   1],
#  ['lots of rumors out there oilers are said to want leopoldadamrd sekerapysyknd sekeraadam leopoldadam for sam gagner who knows',
#   0],
#  ['second last show of the season th annual gift of art with the artists of the kanata civic art gallery stop in',
#   0],
#  ['im assuming that heb ran out of candy and people decided to give out pizza instead because it was busier than super bowl sunday today',
#   0],
#  ['goodnight big day tomorrow im at the school to argentina time because stay to the mallin tomorrow ill tell you what is that',
#   1],
#  ['today is national kissing day coz its no work day tomorrow', 1],
#  ['come meet members of the dawgs in athens this weekend at the red zone friday pm pm coach vince',
#   0],
#  ['this time tomorrow night ill be partying it up in chapel hill happy cantwait',
#   1],
#  ['victor cruz isnt himself todayi know hell get it together in the nd half',
#   0],
#  ['people left in the world and one of them is bill murray theres only people whos the th',
#   0],
#  ['dublins street pub come join us for open mic thursday as the party continues here at dublins street pub cont',
#   0],
#  ['oh man thought the deadline for act was tomorrow have until the th bless',
#   0],
#  ['you realize mizzou made tshirts celebrating their win over kentucky they should commemorate their th place finish on the back',
#   1],
#  ['st movie of the night the vow', 0],
#  ['tts will participate in the love in asia tomorrow at pmkstkbs will broadcast the program on at pmkst on kbs world',
#   0],
#  ['milangenoa rossoneri milanello players have been called up for milangenoa tomorrow at the san siro',
#   0],
#  ['have you called people yet for bruno mars next friday', 0],
#  ['trying for tickets to tomorrows show the late show with david letterman',
#   0],
#  ['tar is addicted to act she just took one on saturday and she just signed up for third test',
#   0],
#  ['in hours know if im gonna see the boys live on may st omgg im sooo scared for tomorrow',
#   0],
#  ['if obama wins am quite sure one of his st major foreign policy hits would be successful resumption of talks with tehran',
#   1],
#  ['awesome response guys the correct answer is sam gagner and brendan smith all of you will be put into the draw this coming thursday jt',
#   1],
#  ['harry styles is leaving one direction and going to form twoman band with ed on the st of february and im married to obama',
#   0],
#  ['not that want to tip my hand but there will be moves in both portfolios tomorrow morning at am cst home run and follow the',
#   0],
#  ['hey channing tony provias from aberdeen hope you get sack on murray this sat',
#   1],
#  ['sings lorenzo beasley he was killed on july th of last year on the corner of rd and king dr mile',
#   0],
#  ['in my tl guys talks about afc vs mufc know guys cant wait till saturday happy epl',
#   1],
#  ['for second time eagles make stop and commit penalty pi on kendricks gives atl another st down groundhog day lives',
#   0],
#  ['lalettura would you be up for full day of movies at mine on thursday happy so far tarzan and the notebook is on the list happy',
#   1],
#  ['like sweet you happy valentines day when its july ill meet you at the shop every tuesday',
#   1],
#  ['queen can you please help me trend biebsmeetbieberwhirls hes coming to my city tomorrow wanna try to meet him',
#   1],
#  ['watched muse on the jonathan ross show last night and promptly had nightmares about screwing everything up on wednesday eeeeek',
#   0],
#  ['mays movies friday night flight with denzel washington dont make plans because just made plans',
#   0],
#  ['hope we dont go to the niners game onda th but wouldnt mind meetin up widd my boo kyle williams inda loccer room stuff lmfao',
#   0],
#  ['rivers to gates for only the rd time this season keep it up chiefs fantasy teams need you',
#   1],
#  ['arianators please help me im girl whos body is very sore and just asking for ariana jennettes goodluck for tomorrow please sad',
#   0],
#  ['google hangout with october th pm pacific pm eastern via askllcoolj llcooljhangout kpoptv pm',
#   0],
#  ['ac milan reportedly want miralem pjanic to join the san siro in january source corriere dello sport transfertalk',
#   0],
#  ['gotta remember to bring dionje candy tomorrow lol he got mad at me today',
#   1],
#  ['great drink specials this saturday as mizzou looks for the upset over florida former mizzou wr brian wheller',
#   0],
#  ['watched the vow for the th time and im still tearing whats wrong with this movie its tooo omg cant even',
#   0],
#  ['see you on march th from argentina to miami no limits for asot and', 0],
#  ['better suit up at the senior bowl friday night', 1],
#  ['egypts president mohamed morsi on monday pardoned all those arrested between the start of the revolution',
#   1],
#  ['kurt convey wins the boys race in with nick diaz coming in nd around rounding out the top was kenny castro',
#   1],
#  ['fyi the ridiculously adorable ladybug larry bird gives his st piece of candy to is our producer director chris kochs gorgeous daughter',
#   1],
#  ['pictures of overdoser st anniversary party at safe house thonglor are online check it out',
#   0],
#  ['realized that ive just spent halloween super bowl sunday and my last two birthdays either in the library or in computer lab',
#   0],
#  ['busted mbirch caught out celebrating the sta cup win with andy carroll and joe hart beer jager',
#   0],
#  ['if they are still looking for center they may want to inquire about sam gagner edmonton needs',
#   0],
#  ['enjoyed the flotus today in fl brilliantsimply put glad voted saturday obama duval',
#   1],
#  ['tonights never mind the buzzcocks has the hilarious noel fielding again happy cant wait to download it tomorrow',
#   1],
#  ['top ten strikers who are on the premier leagues january wishlist via', 0],
#  ['police surgery fri for penygraig residents at the boysgirls club am am pop along and meet your local officer md',
#   0],
#  ['would you like to see cornerback champ bailey play in his twelfth pro bowl this january pro bowl voting',
#   0],
#  ['taking litre of fizzy flavoured water to bed tonight super sunday is gonna result in mouth like ghandis flip flop gacky rank beer',
#   0],
#  ['cant wait to see flight on saturday denzel is one of the best actors in the world alongside leo and de niro',
#   1],
#  ['higham we put nd team out and get beat and you go rafa behave ben you sound like wool calling for rafa',
#   0],
#  ['going to the mizzou game on saturday here with kalebs family what are you doing here',
#   0],
#  ['now yall know all that halloween candy is gonna be on clearance tomorrowyou can save it for valentines day happy',
#   1],
#  ['city game at the ravens stadium saturday at noon dollars to get in will be there who else going',
#   0],
#  ...]

# %%
import csv
with open('train.tsv', 'w', newline='') as fp:
    a = csv.writer(fp, delimiter = "\t")
    data = train_data
    a.writerows(data)
check = pd.read_csv("train.tsv")
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21465 entries, 0 to 21464
# Data columns (total 1 columns):
# text	label    21465 non-null object
# dtypes: object(1)
# memory usage: 167.8+ KB
